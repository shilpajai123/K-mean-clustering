# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rd

# %%
mall=pd.read_csv('C:\\Users\\ADMIN\\Desktop\\mall_data.csv')

# %%
mall.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mall.columns=['id','gender','age','income','score']

# %%
mall.head()
# Out:
#    id  gender  age  income  score
# 0   1    Male   19      15     39
# 1   2    Male   21      15     81
# 2   3  Female   20      16      6
# 3   4  Female   23      16     77
# 4   5  Female   31      17     40

# %%
X=mall.iloc[:,[3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
m=X.shape[0]
n=X.shape[1]
n_iter=100
K=5

# %%
Centroids=np.array([]).reshape(n,0)
for i in range(K):
    rand=rd.randint(0,m-1)
    Centroids=np.c_[Centroids,X[rand]]

# %%
Centroids
# Out:
# array([[79., 77., 62., 62., 78.],
#        [35., 74., 41., 55.,  1.]])

# %%
Output={}

# %%
EuclidianDistance=np.array([]).reshape(m,0)
for k in range(K):
    tempDist=np.sum((X-Centroids[:,k])**2,axis=1)
    EuclidianDistance=np.c_[EuclidianDistance,tempDist]
C=np.argmin(EuclidianDistance,axis=1)+1

# %%
EuclidianDistance
# Out:
# array([[4.1120e+03, 5.0690e+03, 2.2130e+03, 2.4650e+03, 5.4130e+03],
#        [6.2120e+03, 3.8930e+03, 3.8090e+03, 2.8850e+03, 1.0369e+04],
#        [4.8100e+03, 8.3450e+03, 3.3410e+03, 4.5170e+03, 3.8690e+03],
#        [5.7330e+03, 3.7300e+03, 3.4120e+03, 2.6000e+03, 9.6200e+03],
#        [3.8690e+03, 4.7560e+03, 2.0260e+03, 2.2500e+03, 5.2420e+03],
#        [5.5250e+03, 3.6040e+03, 3.2500e+03, 2.4660e+03, 9.3460e+03],
#        [4.5620e+03, 8.1050e+03, 3.1610e+03, 4.3370e+03, 3.6250e+03],
#        [7.2020e+03, 3.8810e+03, 4.7450e+03, 3.4570e+03, 1.2249e+04],
#        [4.6240e+03, 8.4050e+03, 3.2930e+03, 4.5530e+03, 3.4850e+03],
#        [4.9690e+03, 3.3680e+03, 2.8100e+03, 2.1380e+03, 8.5220e+03],
#        [4.0410e+03, 6.9640e+03, 2.5780e+03, 3.5300e+03, 3.6500e+03],
#        [7.6960e+03, 3.9890e+03, 5.2130e+03, 3.7850e+03, 1.3085e+04],
#        [3.8810e+03, 6.7300e+03, 2.4400e+03, 3.3640e+03, 3.5600e+03],
#        [5.2450e+03, 3.2580e+03, 3.0600e+03, 2.2480e+03, 9.1400e+03],
# ...

# %%
Y={}
for k in range(K):
    Y[k+1]=np.array([]).reshape(2,0)
for i in range(m):
    Y[C[i]]=np.c_[Y[C[i]]],X[i]]
for k in range (K):
    Y[k+1]=Y[k+1].T
for k in range (K):
    Centroids[:,k]=np.mean(Y[k+1],axis=0)
# Out:
#   File "<ipython-input-14-5d4fe1b10143>", line 5
#     Y[C[i]]=np.c_[Y[C[i]]],X[i]]
#                                ^
# SyntaxError: invalid syntax

# %%
Y={}
for k in range(K):
    Y[k+1]=np.array([]).reshape(2,0)
for i in range(m):
    Y[C[i]]=np.c_[Y[C[i]], X[i]]

for k in range(K):
    Y[k+1]=Y[k+1].T
    
for k in range(K):
    Centroids[:,k]=np.mean(Y[k+1], axis=0)

# %%
Y

# %%
Centroids

# %%
for i in range(n_iter):
    EuclidianDistance=np.array([]).reshape(m,0)
for k in range(K):
    tempDist=np.sum((X-Centroids[:,k])**2,axis=1)
    EuclidianDistance=np.c_[EuclidianDistance,tempDist]
C=np.argmin(EuclidianDistance,axis=1)+1


Y={}
for k in range(K):
    Y[k+1]=np.array([]).reshape(2,0)
for i in range(m):
    Y[C[i]]=np.c_[Y[C[i]], X[i]]

for k in range(K):
    Y[k+1]=Y[k+1].T
    
for k in range(K):
    Centroids[:,k]=np.mean(Y[k+1], axis=0)
    print(i)
    print(Centroids)
    print('='*50)
Output=Y

# %%
plt.scatter(X[:,0],X[:,1],c='black',label='unclustered data')
plt.xlabel('Income')
plt.ylabel('No of transactions')
plt.legend()
plt.title('plot of data points')
plt.show

# %%
color=['red','blue','green','cyan','magenta']
labels=['cluter1','cluter2','cluter3','cluter4','cluter5']
for k in range(K):
    plt.scatter(Output[k+1][:,0],Output[k+1][:,1],c=color[k],label=labels[k])
plt.scatter(Centroids[0,:],Centroids[1,:],s=300,c='yellow',label='Centroids')
plt.xlabel('Income')
plt.ylabel('No of transactions')
plt.legend()
plt.title('plot of data points')
plt.show

# %%
from sklearn.cluster import KMeans

# %%
data = mall[['income', 'score']]
sse = {}
for k in range(1,11):
   kmeans = KMeans(n_clusters = k,max_iter = 1000).fit(data)
   data["clusters"] = kmeans.labels_
   sse[k] = kmeans.inertia_




plt.figure()
plt.plot(list(sse.keys()),list(sse.values()))
plt.xlabel('NO OF CLUSTER')
plt.ylabel('SSE')
plt.show

# %%
data=pd.read_csv('C:\\Users\\ADMIN\Desktop\GA\\train.csv')

# %%
data.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441      01-01-84        Salaried  ...
# 1               45                1502      31-07-85   Self employed  ...
# 2               45                1497      24-08-85   Self employed  ...
# 3               45                1501      30-12-93   Self employed  ...
# 4               45                1495      09-12-77   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
data.shape
# Out:
# (233154, 41)

# %%
data.isnull().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %%
from datetime import datetime
def conv_dob_year(date_string, str_format="%d-%m-%y"):
    todays_d = datetime.now()
    date_t = datetime.strptime(date_string, str_format)
    delta = todays_d - date_t
    n_days=delta.days
    if(n_days<0):
        n_days = n_days + 100*365
    return n_days/365
def conv_y_m_to_years(y_m_string):
    tmp_1 = y_m_string.split("yrs")
    tmp_2=tmp_1[0].strip()
    tmp_3 = tmp_1[1].split("mon")[0].strip()
    return (int(tmp_2)*365+30*int(tmp_3))/365

# %%
train1=data.copy()

# %%
train1['Date.of.Birth'] = train1['Date.of.Birth'].apply(conv_dob_year)
train1['DisbursalDate'] = train1['DisbursalDate'].apply(conv_dob_year)
train1['Age_as_on_disbursal'] = train1['Date.of.Birth']-train1['DisbursalDate']
train1['AVERAGE.ACCT.AGE']=train1['AVERAGE.ACCT.AGE'].apply(conv_y_m_to_years)
train1['CREDIT.HISTORY.LENGTH']=train1['CREDIT.HISTORY.LENGTH'].apply(conv_y_m_to_years)

# %%
train1['Employment.Type'].fillna('Unknown',inplace=True)
train1['Employment.Type'].value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Unknown            7661
# Name: Employment.Type, dtype: int64

# %%
from sklearn import preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()

train1['Employment.Type']= label_encoder.fit_transform(train1['Employment.Type'])

# %%
train1.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  ...  \
# 0               45                1441      35.498630                0  ...
# 1               45                1502      33.917808                1  ...
# 2               45                1497      33.852055                1  ...
# 3               45                1501      25.495890                1  ...
# 4               45                1495      41.564384                1  ...
#
#    SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# ...

# %%
train1.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default', 'Age_as_on_disbursal'],
#       dtype='object')

# %%
train1['PERFORM_CNS.SCORE.DESCRIPTION'].unique()
# Out:
# array(['No Bureau History Available', 'I-Medium Risk', 'L-Very High Risk',
#        'A-Very Low Risk',
#        'Not Scored: Not Enough Info available on the customer',
#        'D-Very Low Risk', 'M-Very High Risk', 'B-Very Low Risk',
#        'C-Very Low Risk', 'E-Low Risk', 'H-Medium Risk', 'F-Low Risk',
#        'K-High Risk',
#        'Not Scored: No Activity seen on the customer (Inactive)',
#        'Not Scored: Sufficient History Not Available',
#        'Not Scored: No Updates available in last 36 months', 'G-Low Risk',
#        'J-High Risk', 'Not Scored: Only a Guarantor',
#        'Not Scored: More than 50 active Accounts found'], dtype=object)

# %%
train1.nunique()
# Out:
# UniqueID                               233154
# disbursed_amount                        24565
# asset_cost                              46252
# ltv                                      6579
# branch_id                                  82
# supplier_id                              2953
# manufacturer_id                            11
# Current_pincode_ID                       6698
# Date.of.Birth                           15409
# Employment.Type                             3
# DisbursalDate                              84
# State_ID                                   22
# Employee_code_ID                         3270
# MobileNo_Avl_Flag                           1
# Aadhar_flag                                 2
# PAN_flag                                    2
# VoterID_flag                                2
# Driving_flag                                2
# Passport_flag                               2
# PERFORM_CNS.SCORE                         573
# ...

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 42 columns):
# UniqueID                               233154 non-null int64
# disbursed_amount                       233154 non-null int64
# asset_cost                             233154 non-null int64
# ltv                                    233154 non-null float64
# branch_id                              233154 non-null int64
# supplier_id                            233154 non-null int64
# manufacturer_id                        233154 non-null int64
# Current_pincode_ID                     233154 non-null int64
# Date.of.Birth                          233154 non-null float64
# Employment.Type                        233154 non-null int32
# DisbursalDate                          233154 non-null float64
# State_ID                               233154 non-null int64
# Employee_code_ID                       233154 non-null int64
# ...

# %%
train1['PERFORM_CNS.SCORE.DESCRIPTION'] = train1['PERFORM_CNS.SCORE.DESCRIPTION'].map(lambda x: 'risk' if 'Risk' in x else 
                                                                                                'no score' if 'Not Scored' in x 
                                                                                                  else 'no history')
train1['PERFORM_CNS.SCORE.DESCRIPTION'].unique()
# Out:
# array(['no history', 'risk', 'no score'], dtype=object)

# %%
train1['PERFORM_CNS.SCORE.DESCRIPTION']= label_encoder.fit_transform(train1['PERFORM_CNS.SCORE.DESCRIPTION'])

# %%
train1.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  ...  \
# 0               45                1441      35.498630                0  ...
# 1               45                1502      33.917808                1  ...
# 2               45                1497      33.852055                1  ...
# 3               45                1501      25.495890                1  ...
# 4               45                1495      41.564384                1  ...
#
#    SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# ...

# %%
train1['PERFORM_CNS.SCORE.DESCRIPTION'].nunique()
# Out:
# 3

# %%
train1.drop(columns=['loan_default'])
# Out:
#         UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0         420825             50578       58400  89.55         67        22807
# 1         537409             47145       65550  73.23         67        22807
# 2         417566             53278       61360  89.63         67        22807
# 3         624493             57513       66113  88.48         67        22807
# 4         539055             52378       60300  88.39         67        22807
# 5         518279             54513       61900  89.66         67        22807
# 6         529269             46349       61500  76.42         67        22807
# 7         510278             43894       61900  71.89         67        22807
# 8         490213             53713       61973  89.56         67        22807
# 9         510980             52603       61300  86.95         67        22807
# 10        548567             53278       61230  89.83         67        22807
# ...

# %%
train1.columns
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default', 'Age_as_on_disbursal'],
#       dtype='object')

# %%
from sklearn.cluster import KMeans

# %%
train1['CREDIT.HISTORY.LENGTH']=train1['CREDIT.HISTORY.LENGTH'].astype('int64')

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 42 columns):
# UniqueID                               233154 non-null int64
# disbursed_amount                       233154 non-null int64
# asset_cost                             233154 non-null int64
# ltv                                    233154 non-null float64
# branch_id                              233154 non-null int64
# supplier_id                            233154 non-null int64
# manufacturer_id                        233154 non-null int64
# Current_pincode_ID                     233154 non-null int64
# Date.of.Birth                          233154 non-null float64
# Employment.Type                        233154 non-null int32
# DisbursalDate                          233154 non-null float64
# State_ID                               233154 non-null int64
# Employee_code_ID                       233154 non-null int64
# ...

# %%
data = train1[['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
       'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
       'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
       'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
       'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
       'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
       'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
       'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
       'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
       'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
       'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
       'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
        'Age_as_on_disbursal']]
sse = {}
for k in range(1,11):
    kmeans = KMeans(n_clusters = k,max_iter = 1000).fit(data)
    data["clusters"] = kmeans.labels_
    sse[k] = kmeans.inertia_




plt.figure()
plt.plot(list(sse.keys()),list(sse.values()))
plt.xlabel('NO OF CLUSTER')
plt.ylabel('SSE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
m=train1.shape[0]
n=train1.shape[1]
n_iter=100
K=4

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency

class ChiSquare:
    def __init__(self, dataframe):
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfObserved = None
        self.dfExpected = None
        
    def _print_chisquare_result(self, colX, alpha):
        result = ""
        if self.p<alpha:
            result="{0} is IMPORTANT for Prediction".format(colX)
        else:
            result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)

        print(result)
        
    def TestIndependence(self,colX,colY, alpha=0.05):
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)
        
        self.dfObserved = pd.crosstab(Y,X) 
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        self.p = p
        self.chi2 = chi2
        self.dof = dof 
        
        self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)
        
        self._print_chisquare_result(colX,alpha)

# %%
X = train1.drop(['UniqueID', 'loan_default'], axis=1)
ct = ChiSquare(train1)
for c in X.columns:
    ct.TestIndependence(c, 'loan_default')
# Out:
# disbursed_amount is IMPORTANT for Prediction
# asset_cost is IMPORTANT for Prediction
# ltv is IMPORTANT for Prediction
# branch_id is IMPORTANT for Prediction
# supplier_id is IMPORTANT for Prediction
# manufacturer_id is IMPORTANT for Prediction
# Current_pincode_ID is IMPORTANT for Prediction
# Date.of.Birth is NOT an important predictor. (Discard Date.of.Birth from model)
# Employment.Type is IMPORTANT for Prediction
# DisbursalDate is IMPORTANT for Prediction
# State_ID is IMPORTANT for Prediction
# Employee_code_ID is IMPORTANT for Prediction
# MobileNo_Avl_Flag is NOT an important predictor. (Discard MobileNo_Avl_Flag from model)
# Aadhar_flag is IMPORTANT for Prediction
# PAN_flag is NOT an important predictor. (Discard PAN_flag from model)
# VoterID_flag is IMPORTANT for Prediction
# Driving_flag is IMPORTANT for Prediction
# Passport_flag is IMPORTANT for Prediction
# PERFORM_CNS.SCORE is IMPORTANT for Prediction
# PERFORM_CNS.SCORE.DESCRIPTION is IMPORTANT for Prediction
# ...

# %%
data = train1[['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
       'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 
       'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
        'Aadhar_flag',  'VoterID_flag',
       'Driving_flag', 'Passport_flag', 
       'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
       'PRI.OVERDUE.ACCTS',  'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
       'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
       'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
        ]]
sse = {}
for k in range(1,11):
    kmeans = KMeans(n_clusters = k,max_iter = 1000).fit(data)
    data["clusters"] = kmeans.labels_
    sse[k] = kmeans.inertia_




plt.figure()
plt.plot(list(sse.keys()),list(sse.values()))
plt.xlabel('NO OF CLUSTER')
plt.ylabel('SSE')
plt.show
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
